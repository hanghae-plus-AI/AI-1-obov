# %% [markdown]
# <a href="https://colab.research.google.com/github/obov/mnist/blob/main/1_3_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 1 - 1 심화과제
#
# - 본 파일은 overfitting을 해결해보기 위해 CNN을 적용한 코드 및 로그가 남아 있는 파일입니다.
# - 과제를 위한 파일은 [여기](https://github.com/hanghae-plus-AI/AI-1-obov/blob/5e32b8830948f1644dafa75d423fa6b07db09912/CIFAR10.ipynb)에서 확인 하실 수 있습니다.

# %%
"""
HYPER PARAMETERS
"""

LEARNING_RATE = 0.01
NUMBER_OF_EPOCHS = 50
BATCH_SIZE = 256
DATA_SET_NAME = "CIFAR10"
ACTIVATION_FUNCTION = "LeakyReLU"

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform = transforms.ToTensor()

trainset = getattr(torchvision.datasets, DATA_SET_NAME)(
    root="./data", train=True, download=True, transform=transform
)
# Out:
# Files already downloaded and verified

# %%
from matplotlib import pyplot as plt


print(len(trainset))
print(trainset[0][0].shape, trainset[0][1])
plt.imshow(trainset[0][0][0], cmap="gray")
# Out:
# 50000
# torch.Size([3, 32, 32]) 6

# %%
from torch.utils.data import Subset


batch_size = BATCH_SIZE
# 0부터 47999까지는 훈련용, 48000부터 59999까지는 검증용으로 설정
train_indices = list(range(40000))
val_indices = list(range(40000, 50000))

train_dataset = Subset(trainset, train_indices)
val_dataset = Subset(trainset, val_indices)

train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True
)
val_loader = torch.utils.data.DataLoader(
    val_dataset, batch_size=batch_size, shuffle=False
)

# %%
dataiter = iter(train_loader)
images, labels = next(dataiter)
print(images.shape, labels.shape)
# Out:
# torch.Size([256, 3, 32, 32]) torch.Size([256])

# %%
from torch import nn

output_dim = 10


class Model(nn.Module):
    def __init__(
        self,
        input_dim,
        n_dim,
        output_dim,
        activation_function="LeakyReLU",
        dropout_prob=0.0,
    ):
        super().__init__()

        # 레이어 정의
        self.layer1 = nn.Linear(input_dim, n_dim)
        self.layer2 = nn.Linear(n_dim, n_dim)
        self.layer3 = nn.Linear(n_dim, n_dim)
        self.layer4 = nn.Linear(n_dim, output_dim)

        # 활성화 함수 설정
        self.act = getattr(nn, activation_function)()

        # 드롭아웃 레이어 (dropout_prob이 0이면 드롭아웃이 적용되지 않음)
        self.dropout = nn.Dropout(dropout_prob)

    def forward(self, x):
        x = torch.flatten(x, start_dim=1)  # 입력을 1D 벡터로 Flatten

        # 레이어 1 -> 활성화 함수 -> 드롭아웃
        x = self.act(self.layer1(x))
        x = self.dropout(x)

        # 레이어 2 -> 활성화 함수 -> 드롭아웃
        x = self.act(self.layer2(x))
        x = self.dropout(x)

        # 레이어 3 -> 활성화 함수 -> 드롭아웃
        x = self.act(self.layer2(x))
        x = self.dropout(x)

        # 마지막 레이어 (출력 레이어)
        x = self.layer4(x)  # 마지막 레이어에서는 활성화 함수 필요 없음
        return x


class CNNModel(nn.Module):
    def __init__(
        self,
        input_channels=3,
        n_dim=64,
        output_dim=10,
        activation_function="LeakyReLU",
        dropout_prob=0.5,
    ):
        super().__init__()

        # 첫 번째 블록
        self.conv1 = nn.Conv2d(
            in_channels=input_channels, out_channels=n_dim, kernel_size=3, padding=1
        )
        self.bn1 = nn.BatchNorm2d(n_dim)

        # 두 번째 블록
        self.conv2 = nn.Conv2d(
            in_channels=n_dim, out_channels=n_dim * 2, kernel_size=3, padding=1
        )
        self.bn2 = nn.BatchNorm2d(n_dim * 2)

        # 세 번째 블록
        self.conv3 = nn.Conv2d(
            in_channels=n_dim * 2, out_channels=n_dim * 4, kernel_size=3, padding=1
        )
        self.bn3 = nn.BatchNorm2d(n_dim * 4)

        self.pool = nn.MaxPool2d(2, 2)
        self.act = getattr(nn, activation_function)()
        self.dropout = nn.Dropout(dropout_prob)

        # Fully Connected Layer를 Global Average Pooling으로 대체
        self.global_avg_pool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(n_dim * 4, output_dim)

    def forward(self, x):
        # 첫 번째 블록
        x = self.pool(self.act(self.bn1(self.conv1(x))))
        x = self.dropout(x)

        # 두 번째 블록
        x = self.pool(self.act(self.bn2(self.conv2(x))))
        x = self.dropout(x)

        # 세 번째 블록
        x = self.pool(self.act(self.bn3(self.conv3(x))))
        x = self.dropout(x)

        # Global Average Pooling
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)

        # Fully Connected Layer
        x = self.fc(x)
        return x


input_dim = 3 * 32 * 32  # 32x32 크기의 3채널(RGB) 이미지를 Flatten한 크기

device = torch.device("mps")

model_leaky_ReLU_plot1_sgd = CNNModel(3, 64, 10).to(device)  # plot1
model_leaky_ReLU_plot1_adam = CNNModel(3, 64, 10).to(device)  # plot1
model_leaky_ReLU_plot2 = CNNModel(3, 64, 10).to(device)  # plot2
model_sigmoid = CNNModel(3, 64, 10, "Sigmoid").to(device)  # plot2
model_leaky_ReLU_dropout = CNNModel(3, 64, 10, "LeakyReLU", 0.5).to(device)  # plot3

# %%
from torch.optim import SGD, Adam

lr = LEARNING_RATE

optimizer_sgd = SGD(model_leaky_ReLU_plot1_sgd.parameters(), lr=lr)  # plot1
optimizer_adam_plot1 = Adam(model_leaky_ReLU_plot1_adam.parameters(), lr=lr)  # plot1
optimizer_adam_plot2 = Adam(model_leaky_ReLU_plot2.parameters(), lr=lr)  # plot2
optimizer_adam_sigmoid = Adam(model_sigmoid.parameters(), lr=lr)  # plot2
optimizer_dropout = Adam(model_leaky_ReLU_dropout.parameters(), lr=lr)  # plot3

# %%
n_epochs = NUMBER_OF_EPOCHS

import matplotlib.pyplot as plt
from tabulate import tabulate

CEL = nn.CrossEntropyLoss()
train_accuracies = []
val_accuracies = []

device = "mps"


def train_and_validate(model, optimizer):
    CEL = nn.CrossEntropyLoss()
    train_accuracies = []
    val_accuracies = []

    def accuracy(model, dataloader):
        cnt = 0
        acc = 0
        for data in dataloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            preds = model(inputs)
            preds = torch.argmax(preds, dim=-1)

            cnt += labels.shape[0]
            acc += (labels == preds).sum().item()

        return acc / cnt

    for epoch in range(n_epochs):
        model.train()  # 훈련 모드로 전환
        total_loss = 0.0

        # 훈련 루프
        for data in train_loader:
            model.zero_grad()
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            preds = model(inputs)
            loss = CEL(preds, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        # 훈련 정확도
        train_accuracy = accuracy(model, train_loader)
        train_accuracies.append(train_accuracy)

        # 검증 루프
        model.eval()  # 검증 모드로 전환
        val_loss = 0.0
        with torch.no_grad():  # 검증할 때는 no_grad()를 사용하여 파라미터 업데이트를 하지 않음
            for data in val_loader:
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                preds = model(inputs)
                loss = CEL(preds, labels)
                val_loss += loss.item()

        # 검증 정확도
        val_accuracy = accuracy(model, val_loader)
        val_accuracies.append(val_accuracy)
        # Epoch이 끝난 후 테이블로 결과 출력
        table = [
            ["", "Loss", "Accuracy"],
            ["Train", f"{total_loss/2:.2f}  ", f"{train_accuracy:.2%}"],
            ["Validate", f"{val_loss*2:.2f}  ", f"{val_accuracy:.2%}"],
        ]

        print(f"\nEpoch {epoch+1:3d}")
        print(tabulate(table, headers="firstrow", tablefmt="plain", stralign="center"))

    return train_accuracies, val_accuracies

# %%
import numpy as np


def plot_acc(train_accs, test_accs, label1="train", label2="validate"):
    x = np.arange(len(train_accs))

    plt.plot(x, train_accs, label=label1)
    plt.plot(x, test_accs, label=label2)
    plt.legend()
    plt.show()

# %%
# PLOT1
sgd_train_accuracies, _ = train_and_validate(model_leaky_ReLU_plot1_sgd, optimizer_sgd)
adam_train_accuracies, _ = train_and_validate(
    model_leaky_ReLU_plot1_adam, optimizer_adam_plot1
)
# Out:
# Epoch   1
#             Loss   Accuracy
#  Train    164.12    26.30%
# Validate  175.55    16.64%
#
# Epoch   2
#             Loss   Accuracy
#  Train    152.39    30.26%
# Validate  169.95    18.84%
#
# Epoch   3
#             Loss   Accuracy
#  Train    146.19    32.52%
# Validate  164.35    21.53%
#
# Epoch   4
#             Loss   Accuracy
#  Train    141.09    34.53%
# Validate  159.47    22.86%
#
# Epoch   5
#             Loss   Accuracy
#  Train    137.31    34.88%
# Validate  158.45    22.45%
#
# Epoch   6
#             Loss   Accuracy
#  Train    134.42    36.33%
# Validate  153.62    25.70%
#
# Epoch   7
#             Loss   Accuracy
#  Train    132.23    37.70%
# Validate  151.54    25.16%
#
# Epoch   8
#             Loss   Accuracy
#  Train    130.59    38.58%
# Validate  150.22    26.30%
#
# Epoch   9
#             Loss   Accuracy
#  Train    129.07    38.91%
# Validate  150.57    26.50%
#
# Epoch  10
#             Loss   Accuracy
#  Train    127.44    40.73%
# Validate  147.85    27.98%
#
# Epoch  11
#             Loss   Accuracy
#  Train    126.19    38.74%
# Validate  151.18    27.11%
#
# Epoch  12
#             Loss   Accuracy
#  Train    125.1     41.44%
# Validate  151.21    26.65%
#
# Epoch  13
#             Loss   Accuracy
#  Train    123.04    41.84%
# Validate  150.31    27.18%
#
# Epoch  14
#             Loss   Accuracy
#  Train    122       43.31%
# Validate  152.23    27.04%
#
# Epoch  15
#             Loss   Accuracy
#  Train    120.45    44.30%
# Validate  152.44    26.85%
#
# Epoch  16
#             Loss   Accuracy
#  Train    119.28    44.48%
# Validate  155.2     26.36%
#
# Epoch  17
#             Loss   Accuracy
#  Train    118.21    45.31%
# Validate  153.41    27.39%
#
# Epoch  18
#             Loss   Accuracy
#  Train    117.41    45.18%
# Validate  150.86    28.50%
#
# Epoch  19
#             Loss   Accuracy
#  Train    116.05    46.09%
# Validate  151.03    28.65%
#
# Epoch  20
#             Loss   Accuracy
#  Train    114.96    46.31%
# Validate  152.63    28.06%
#
# Epoch  21
#             Loss   Accuracy
#  Train    114.12    45.81%
# Validate  155.58    28.59%
#
# Epoch  22
#             Loss   Accuracy
#  Train    113.82    47.22%
# Validate  152.46    29.42%
#
# Epoch  23
#             Loss   Accuracy
#  Train    113       45.84%
# Validate  158.66    27.75%
#
# Epoch  24
#             Loss   Accuracy
#  Train    112.05    47.99%
# Validate  148.54    31.51%
#
# Epoch  25
#             Loss   Accuracy
#  Train    110.98    47.48%
# Validate  154.05    30.32%
#
# Epoch  26
#             Loss   Accuracy
#  Train    110.56    48.15%
# Validate  151.03    31.07%
#
# Epoch  27
#             Loss   Accuracy
#  Train    109.88    48.97%
# Validate  150.18    31.89%
#
# Epoch  28
#             Loss   Accuracy
#  Train    109.36    48.85%
# Validate  152.22    31.47%
#
# Epoch  29
#             Loss   Accuracy
#  Train    108.68    46.20%
# Validate  153.06    31.73%
#
# Epoch  30
#             Loss   Accuracy
#  Train    108.45    49.83%
# Validate  145.81    33.51%
#
# Epoch  31
#             Loss   Accuracy
#  Train    107.76    50.53%
# Validate  148.81    32.78%
#
# Epoch  32
#             Loss   Accuracy
#  Train    107.24    50.44%
# Validate  146.95    33.82%
#
# Epoch  33
#             Loss   Accuracy
#  Train    106.82    50.89%
# Validate  143.91    34.15%
#
# Epoch  34
#             Loss   Accuracy
#  Train    106.59    49.83%
# Validate  147.07    33.76%
#
# Epoch  35
#             Loss   Accuracy
#  Train    105.56    50.06%
# Validate  146.65    33.65%
#
# Epoch  36
#             Loss   Accuracy
#  Train    105.16    51.54%
# Validate  144.38    34.58%
#
# Epoch  37
#             Loss   Accuracy
#  Train    104.59    50.12%
# Validate  142.91    34.44%
#
# Epoch  38
#             Loss   Accuracy
#  Train    104.52    52.63%
# Validate  139.82    36.38%
#
# Epoch  39
#             Loss   Accuracy
#  Train    103.35    51.72%
# Validate  139.81    36.09%
#
# Epoch  40
#             Loss   Accuracy
#  Train    103.53    51.91%
# Validate  140.67    36.99%
#
# Epoch  41
#             Loss   Accuracy
#  Train    103.39    50.98%
# Validate  142.02    36.17%
#
# Epoch  42
#             Loss   Accuracy
#  Train    102.21    51.92%
# Validate  139.5     36.43%
#
# Epoch  43
#             Loss   Accuracy
#  Train    101.92    52.47%
# Validate  133.97    38.67%
#
# Epoch  44
#             Loss   Accuracy
#  Train    101.84    53.04%
# Validate  131.02    39.15%
#
# Epoch  45
#             Loss   Accuracy
#  Train    101.49    53.76%
# Validate  134.06    38.37%
#
# Epoch  46
#             Loss   Accuracy
#  Train    101.15    52.70%
# Validate  134.5     39.05%
#
# Epoch  47
#             Loss   Accuracy
#  Train    100.51    53.57%
# Validate  132.8     39.02%
#
# Epoch  48
#             Loss   Accuracy
#  Train    100.62    53.32%
# Validate  130.37    40.19%
#
# Epoch  49
#             Loss   Accuracy
#  Train     99.91    52.81%
# Validate  134.66    39.00%
#
# Epoch  50
#             Loss   Accuracy
#  Train     99.46    54.30%
# Validate  130.58    39.72%
#
# Epoch   1
#             Loss   Accuracy
#  Train    130.19    46.80%
# Validate  117.19    46.38%
#
# Epoch   2
#             Loss   Accuracy
#  Train    103.78    53.82%
# Validate   99.67    55.14%
#
# Epoch   3
#             Loss   Accuracy
#  Train     92.97    58.15%
# Validate   89.24    62.09%
#
# Epoch   4
#             Loss   Accuracy
#  Train     87.19    59.64%
# Validate   85.26    63.16%
#
# Epoch   5
#             Loss   Accuracy
#  Train     81.95    62.91%
# Validate   85.15    62.33%
#
# Epoch   6
#             Loss   Accuracy
#  Train     78.84    65.87%
# Validate   77.31    66.70%
#
# Epoch   7
#             Loss   Accuracy
#  Train     76.03    67.20%
# Validate   73.97    68.05%
#
# Epoch   8
#             Loss   Accuracy
#  Train     73.71    67.63%
# Validate   74.79    68.01%
#
# Epoch   9
#             Loss   Accuracy
#  Train     71.63    69.31%
# Validate   70.63    69.36%
#
# Epoch  10
#             Loss   Accuracy
#  Train     70.12    70.06%
# Validate   71.04    69.63%
#
# Epoch  11
#             Loss   Accuracy
#  Train     68.38    70.30%
# Validate   66.83    71.23%
#
# Epoch  12
#             Loss   Accuracy
#  Train     67.6     69.98%
# Validate   70.28    69.25%
#
# Epoch  13
#             Loss   Accuracy
#  Train     66.26    71.45%
# Validate   62.4     73.59%
#
# Epoch  14
#             Loss   Accuracy
#  Train     64.94    71.91%
# Validate   64       71.87%
#
# Epoch  15
#             Loss   Accuracy
#  Train     64.24    72.04%
# Validate   61.68    73.59%
#
# Epoch  16
#             Loss   Accuracy
#  Train     63.2     72.48%
# Validate   63.42    72.60%
#
# Epoch  17
#             Loss   Accuracy
#  Train     61.9     73.38%
# Validate   58.76    74.87%
#
# Epoch  18
#             Loss   Accuracy
#  Train     61.07    73.37%
# Validate   60.12    73.83%
#
# Epoch  19
#             Loss   Accuracy
#  Train     60.62    73.38%
# Validate   60.61    74.21%
#
# Epoch  20
#             Loss   Accuracy
#  Train     59.77    73.86%
# Validate   59.91    74.21%
#
# Epoch  21
#             Loss   Accuracy
#  Train     59.33    73.82%
# Validate   60.6     73.90%
#
# Epoch  22
#             Loss   Accuracy
#  Train     58.35    74.22%
# Validate   60.2     74.30%
#
# Epoch  23
#             Loss   Accuracy
#  Train     58.28    74.51%
# Validate   59.09    74.55%
#
# Epoch  24
#             Loss   Accuracy
#  Train     57.27    74.95%
# Validate   58.16    74.87%
#
# Epoch  25
#             Loss   Accuracy
#  Train     56.99    74.46%
# Validate   56.72    75.39%
#
# Epoch  26
#             Loss   Accuracy
#  Train     56.26    75.42%
# Validate   55.67    75.92%
#
# Epoch  27
#             Loss   Accuracy
#  Train     55.87    76.11%
# Validate   56.08    75.87%
#
# Epoch  28
#             Loss   Accuracy
#  Train     55.69    75.80%
# Validate   52.93    77.37%
#
# Epoch  29
#             Loss   Accuracy
#  Train     54.86    75.41%
# Validate   55.93    75.72%
#
# Epoch  30
#             Loss   Accuracy
#  Train     54.87    75.61%
# Validate   53.15    77.29%
#
# Epoch  31
#             Loss   Accuracy
#  Train     54.25    76.14%
# Validate   54.15    76.84%
#
# Epoch  32
#             Loss   Accuracy
#  Train     54.22    75.24%
# Validate   53.71    77.05%
#
# Epoch  33
#             Loss   Accuracy
#  Train     53.19    77.23%
# Validate   52.1     77.70%
#
# Epoch  34
#             Loss   Accuracy
#  Train     52.85    75.79%
# Validate   55.19    76.47%
#
# Epoch  35
#             Loss   Accuracy
#  Train     53.06    76.98%
# Validate   51.82    77.85%
#
# Epoch  36
#             Loss   Accuracy
#  Train     52.11    77.04%
# Validate   51.6     77.93%
#
# Epoch  37
#             Loss   Accuracy
#  Train     52.06    77.33%
# Validate   53.16    77.06%
#
# Epoch  38
#             Loss   Accuracy
#  Train     51.52    77.64%
# Validate   50.87    78.33%
#
# Epoch  39
#             Loss   Accuracy
#  Train     51.85    76.83%
# Validate   51.24    77.77%
#
# Epoch  40
#             Loss   Accuracy
#  Train     51.2     77.59%
# Validate   50.01    78.52%
#
# Epoch  41
#             Loss   Accuracy
#  Train     51.1     77.59%
# Validate   50.37    78.05%
#
# Epoch  42
#             Loss   Accuracy
#  Train     51.22    77.98%
# Validate   52.19    77.34%
#
# Epoch  43
#             Loss   Accuracy
#  Train     50.63    77.80%
# Validate   49.23    79.04%
#
# Epoch  44
#             Loss   Accuracy
#  Train     50.34    77.52%
# Validate   49.55    79.23%
#
# Epoch  45
#             Loss   Accuracy
#  Train     49.71    77.39%
# Validate   52.71    77.48%
#
# Epoch  46
#             Loss   Accuracy
#  Train     50.18    77.80%
# Validate   48.88    79.56%
#
# Epoch  47
#             Loss   Accuracy
#  Train     49.94    78.23%
# Validate   48.81    79.18%
#
# Epoch  48
#             Loss   Accuracy
#  Train     49.47    78.02%
# Validate   50.17    78.81%
#
# Epoch  49
#             Loss   Accuracy
#  Train      49.6    78.22%
# Validate    47.9    79.74%
#
# Epoch  50
#             Loss   Accuracy
#  Train      48.7    78.70%
# Validate    47.6    79.80%

# %%
# PLOT1
plot_acc(sgd_train_accuracies, adam_train_accuracies, "sgd", "adam")

# %%
# PLOT2
leaky_ReLU_train_accuracies, _ = train_and_validate(
    model_leaky_ReLU_plot2, optimizer_adam_plot2
)
sigmoid_train_accuracies, _ = train_and_validate(model_sigmoid, optimizer_adam_sigmoid)
# Out:
# Epoch   1
#             Loss   Accuracy
#  Train    129.47    47.44%
# Validate  113.58    49.36%
#
# Epoch   2
#             Loss   Accuracy
#  Train    103.54    55.41%
# Validate  100.66    55.55%
#
# Epoch   3
#             Loss   Accuracy
#  Train     93.12    60.54%
# Validate   88.27    61.55%
#
# Epoch   4
#             Loss   Accuracy
#  Train     86.82    63.04%
# Validate   84.25    63.95%
#
# Epoch   5
#             Loss   Accuracy
#  Train     81.79    64.70%
# Validate   77.26    66.01%
#
# Epoch   6
#             Loss   Accuracy
#  Train     78.48    64.68%
# Validate   74.26    67.63%
#
# Epoch   7
#             Loss   Accuracy
#  Train     76.1     66.24%
# Validate   77.33    66.23%
#
# Epoch   8
#             Loss   Accuracy
#  Train     74.13    67.45%
# Validate   69.83    69.44%
#
# Epoch   9
#             Loss   Accuracy
#  Train     72.12    68.20%
# Validate   76.03    66.21%
#
# Epoch  10
#             Loss   Accuracy
#  Train     70.4     67.15%
# Validate   70.73    68.84%
#
# Epoch  11
#             Loss   Accuracy
#  Train     69.33    68.78%
# Validate   66.86    70.59%
#
# Epoch  12
#             Loss   Accuracy
#  Train     67.4     70.44%
# Validate   66.86    71.22%
#
# Epoch  13
#             Loss   Accuracy
#  Train     66.8     70.78%
# Validate   65.47    71.66%
#
# Epoch  14
#             Loss   Accuracy
#  Train     64.79    71.43%
# Validate   60.69    74.23%
#
# Epoch  15
#             Loss   Accuracy
#  Train     64.6     72.25%
# Validate   60.46    74.30%
#
# Epoch  16
#             Loss   Accuracy
#  Train     63.3     71.35%
# Validate   64.36    72.71%
#
# Epoch  17
#             Loss   Accuracy
#  Train     62.4     72.51%
# Validate   61.86    73.03%
#
# Epoch  18
#             Loss   Accuracy
#  Train     61.29    73.01%
# Validate   63.18    72.65%
#
# Epoch  19
#             Loss   Accuracy
#  Train     60.56    73.56%
# Validate   58.78    74.62%
#
# Epoch  20
#             Loss   Accuracy
#  Train     59.68    73.56%
# Validate   58.12    75.43%
#
# Epoch  21
#             Loss   Accuracy
#  Train     59.03    73.56%
# Validate   58.58    74.89%
#
# Epoch  22
#             Loss   Accuracy
#  Train     58.22    74.11%
# Validate   58.52    74.33%
#
# Epoch  23
#             Loss   Accuracy
#  Train     57.27    74.36%
# Validate   56.08    76.61%
#
# Epoch  24
#             Loss   Accuracy
#  Train     57.33    74.29%
# Validate   55.15    76.79%
#
# Epoch  25
#             Loss   Accuracy
#  Train     56.61    75.17%
# Validate   54.43    76.54%
#
# Epoch  26
#             Loss   Accuracy
#  Train     56.46    75.56%
# Validate   55.5     76.35%
#
# Epoch  27
#             Loss   Accuracy
#  Train     55.95    75.22%
# Validate   53.8     77.47%
#
# Epoch  28
#             Loss   Accuracy
#  Train     55.23    75.43%
# Validate   52.14    77.99%
#
# Epoch  29
#             Loss   Accuracy
#  Train     54.46    76.43%
# Validate   53.79    77.23%
#
# Epoch  30
#             Loss   Accuracy
#  Train     54.11    75.51%
# Validate   53.36    77.27%
#
# Epoch  31
#             Loss   Accuracy
#  Train     54.7     76.11%
# Validate   54.55    76.73%
#
# Epoch  32
#             Loss   Accuracy
#  Train     53.56    77.12%
# Validate   52.53    77.59%
#
# Epoch  33
#             Loss   Accuracy
#  Train     52.96    76.56%
# Validate   53.37    77.57%
#
# Epoch  34
#             Loss   Accuracy
#  Train     52.82    77.20%
# Validate   53.28    77.36%
#
# Epoch  35
#             Loss   Accuracy
#  Train     53.22    76.78%
# Validate   54.65    76.54%
#
# Epoch  36
#             Loss   Accuracy
#  Train     52.76    77.49%
# Validate   53.01    77.31%
#
# Epoch  37
#             Loss   Accuracy
#  Train     51.53    77.55%
# Validate   49.94    78.69%
#
# Epoch  38
#             Loss   Accuracy
#  Train     51.64    77.28%
# Validate   52.3     77.19%
#
# Epoch  39
#             Loss   Accuracy
#  Train     52.06    77.48%
# Validate   49.85    78.95%
#
# Epoch  40
#             Loss   Accuracy
#  Train     51.2     76.89%
# Validate   50.54    78.67%
#
# Epoch  41
#             Loss   Accuracy
#  Train     51.33    77.58%
# Validate   50.25    78.56%
#
# Epoch  42
#             Loss   Accuracy
#  Train     50.94    78.05%
# Validate   49.69    78.62%
#
# Epoch  43
#             Loss   Accuracy
#  Train     49.92    77.83%
# Validate   50.67    78.61%
#
# Epoch  44
#             Loss   Accuracy
#  Train     50.88    78.39%
# Validate   50.39    78.51%
#
# Epoch  45
#             Loss   Accuracy
#  Train     49.56    78.00%
# Validate   51.1     78.31%
#
# Epoch  46
#             Loss   Accuracy
#  Train     49.43    78.11%
# Validate   48.02    79.82%
#
# Epoch  47
#             Loss   Accuracy
#  Train     49.59    78.64%
# Validate   48.39    79.75%
#
# Epoch  48
#             Loss   Accuracy
#  Train     48.86    78.87%
# Validate   49.57    79.13%
#
# Epoch  49
#             Loss   Accuracy
#  Train     48.74    78.56%
# Validate   51.82    77.87%
#
# Epoch  50
#             Loss   Accuracy
#  Train     48.75    78.44%
# Validate   47.31    79.95%
#
# Epoch   1
#             Loss   Accuracy
#  Train    152.69    31.93%
# Validate  139.09    33.28%
#
# Epoch   2
#             Loss   Accuracy
#  Train    130.12    39.81%
# Validate  125.91    41.37%
#
# Epoch   3
#             Loss   Accuracy
#  Train    119.2     45.61%
# Validate  123.37    43.37%
#
# Epoch   4
#             Loss   Accuracy
#  Train    111.49    47.15%
# Validate  114.68    47.34%
#
# Epoch   5
#             Loss   Accuracy
#  Train    104.89    52.34%
# Validate  104.59    53.42%
#
# Epoch   6
#             Loss   Accuracy
#  Train    101.38    54.60%
# Validate   98.31    55.90%
#
# Epoch   7
#             Loss   Accuracy
#  Train     98       56.09%
# Validate   97.96    56.87%
#
# Epoch   8
#             Loss   Accuracy
#  Train     95.32    58.39%
# Validate   94.2     58.45%
#
# Epoch   9
#             Loss   Accuracy
#  Train     92.08    57.99%
# Validate   95.39    58.07%
#
# Epoch  10
#             Loss   Accuracy
#  Train     90.33    58.84%
# Validate   90.64    59.98%
#
# Epoch  11
#             Loss   Accuracy
#  Train     88.68    59.72%
# Validate   85.49    62.54%
#
# Epoch  12
#             Loss   Accuracy
#  Train     86.34    62.19%
# Validate   84.56    63.57%
#
# Epoch  13
#             Loss   Accuracy
#  Train     84.68    61.02%
# Validate   82.55    64.24%
#
# Epoch  14
#             Loss   Accuracy
#  Train     83.72    62.86%
# Validate   80.5     65.74%
#
# Epoch  15
#             Loss   Accuracy
#  Train     82.26    62.76%
# Validate   81.81    65.13%
#
# Epoch  16
#             Loss   Accuracy
#  Train     81.52    64.05%
# Validate   83.77    63.58%
#
# Epoch  17
#             Loss   Accuracy
#  Train     80.8     63.82%
# Validate   88.05    61.52%
#
# Epoch  18
#             Loss   Accuracy
#  Train     78.65    65.10%
# Validate   80.35    64.79%
#
# Epoch  19
#             Loss   Accuracy
#  Train     78.12    64.98%
# Validate   81.76    63.74%
#
# Epoch  20
#             Loss   Accuracy
#  Train     76.97    65.81%
# Validate   79.36    64.87%
#
# Epoch  21
#             Loss   Accuracy
#  Train     76.13    65.69%
# Validate   79.64    64.67%
#
# Epoch  22
#             Loss   Accuracy
#  Train     75.89    65.42%
# Validate   74.76    67.40%
#
# Epoch  23
#             Loss   Accuracy
#  Train     75.17    66.13%
# Validate   80.85    64.35%
#
# Epoch  24
#             Loss   Accuracy
#  Train     73.89    65.98%
# Validate   78.03    65.28%
#
# Epoch  25
#             Loss   Accuracy
#  Train     73.68    67.55%
# Validate   75.96    66.63%
#
# Epoch  26
#             Loss   Accuracy
#  Train     72.36    67.54%
# Validate   71.29    69.15%
#
# Epoch  27
#             Loss   Accuracy
#  Train     71.49    67.94%
# Validate   74.41    67.97%
#
# Epoch  28
#             Loss   Accuracy
#  Train     71.46    69.33%
# Validate   73.58    67.95%
#
# Epoch  29
#             Loss   Accuracy
#  Train     70.31    68.92%
# Validate   74.46    67.43%
#
# Epoch  30
#             Loss   Accuracy
#  Train     69.36    68.88%
# Validate   74.14    67.03%
#
# Epoch  31
#             Loss   Accuracy
#  Train     69.23    68.05%
# Validate   78.12    65.10%
#
# Epoch  32
#             Loss   Accuracy
#  Train     69.13    69.35%
# Validate   74.82    67.09%
#
# Epoch  33
#             Loss   Accuracy
#  Train     68.25    70.25%
# Validate   69.58    70.15%
#
# Epoch  34
#             Loss   Accuracy
#  Train     67.24    70.22%
# Validate   71.59    68.39%
#
# Epoch  35
#             Loss   Accuracy
#  Train     66.98    70.44%
# Validate   69.23    70.15%
#
# Epoch  36
#             Loss   Accuracy
#  Train     66.05    70.38%
# Validate   71.77    68.70%
#
# Epoch  37
#             Loss   Accuracy
#  Train     66.23    70.89%
# Validate   72.42    68.28%
#
# Epoch  38
#             Loss   Accuracy
#  Train     65.75    71.05%
# Validate   73.3     67.87%
#
# Epoch  39
#             Loss   Accuracy
#  Train     65       71.46%
# Validate   68.04    70.57%
#
# Epoch  40
#             Loss   Accuracy
#  Train     64.17    71.47%
# Validate   68.64    70.24%
#
# Epoch  41
#             Loss   Accuracy
#  Train     64.6     71.90%
# Validate   68.46    70.49%
#
# Epoch  42
#             Loss   Accuracy
#  Train     63.62    71.41%
# Validate   68.61    70.03%
#
# Epoch  43
#             Loss   Accuracy
#  Train     62.99    71.62%
# Validate   69.2     69.70%
#
# Epoch  44
#             Loss   Accuracy
#  Train     62.59    71.55%
# Validate   73.07    67.46%
#
# Epoch  45
#             Loss   Accuracy
#  Train     62.23    71.91%
# Validate   73.19    67.49%
#
# Epoch  46
#             Loss   Accuracy
#  Train     61.87    72.27%
# Validate   66.57    71.17%
#
# Epoch  47
#             Loss   Accuracy
#  Train     61.24    72.30%
# Validate   66.41    71.01%
#
# Epoch  48
#             Loss   Accuracy
#  Train     60.39    73.03%
# Validate   68.25    70.02%
#
# Epoch  49
#             Loss   Accuracy
#  Train     60.38    73.20%
# Validate   66.39    71.13%
#
# Epoch  50
#             Loss   Accuracy
#  Train     60.17    73.29%
# Validate   63.34    72.19%

# %%
# PLOT2
plot_acc(leaky_ReLU_train_accuracies, sigmoid_train_accuracies, "leaky_ReLU", "sigmoid")

# %%
# PLOT3
dropout_train_accuracies, dropout_validate_accuracies = train_and_validate(
    model_leaky_ReLU_dropout, optimizer_dropout
)
# Out:
# Epoch   1
#             Loss   Accuracy
#  Train    132.23    48.36%
# Validate  114.78    47.96%
#
# Epoch   2
#             Loss   Accuracy
#  Train    105.45    53.30%
# Validate  103.07    52.65%
#
# Epoch   3
#             Loss   Accuracy
#  Train     95.26    59.62%
# Validate   89.41    60.77%
#
# Epoch   4
#             Loss   Accuracy
#  Train     87.62    61.84%
# Validate   81.31    64.82%
#
# Epoch   5
#             Loss   Accuracy
#  Train     83.31    63.26%
# Validate   79.38    65.61%
#
# Epoch   6
#             Loss   Accuracy
#  Train     79.57    65.04%
# Validate   77.36    65.83%
#
# Epoch   7
#             Loss   Accuracy
#  Train     76.44    66.57%
# Validate   72.44    68.37%
#
# Epoch   8
#             Loss   Accuracy
#  Train     74.29    67.47%
# Validate   72.98    67.97%
#
# Epoch   9
#             Loss   Accuracy
#  Train     72.79    67.85%
# Validate   72.67    68.46%
#
# Epoch  10
#             Loss   Accuracy
#  Train     71.05    69.70%
# Validate   67.98    70.89%
#
# Epoch  11
#             Loss   Accuracy
#  Train     69.3     69.94%
# Validate   66.33    71.39%
#
# Epoch  12
#             Loss   Accuracy
#  Train     67.55    71.02%
# Validate   66.53    71.31%
#
# Epoch  13
#             Loss   Accuracy
#  Train     66.68    71.30%
# Validate   67.12    70.99%
#
# Epoch  14
#             Loss   Accuracy
#  Train     65.53    71.16%
# Validate   68.61    70.17%
#
# Epoch  15
#             Loss   Accuracy
#  Train     64.12    71.77%
# Validate   65.12    72.23%
#
# Epoch  16
#             Loss   Accuracy
#  Train     63.31    72.25%
# Validate   63.36    73.30%
#
# Epoch  17
#             Loss   Accuracy
#  Train     61.95    72.80%
# Validate   63.01    73.00%
#
# Epoch  18
#             Loss   Accuracy
#  Train     61.95    73.35%
# Validate   59.3     75.00%
#
# Epoch  19
#             Loss   Accuracy
#  Train     60.94    73.70%
# Validate   60.04    74.04%
#
# Epoch  20
#             Loss   Accuracy
#  Train     60.43    74.26%
# Validate   58.67    75.17%
#
# Epoch  21
#             Loss   Accuracy
#  Train     59.94    74.03%
# Validate   57.29    75.66%
#
# Epoch  22
#             Loss   Accuracy
#  Train     58.72    73.83%
# Validate   59.1     74.37%
#
# Epoch  23
#             Loss   Accuracy
#  Train     58.32    73.97%
# Validate   56.18    75.35%
#
# Epoch  24
#             Loss   Accuracy
#  Train     58.03    74.87%
# Validate   57.41    75.09%
#
# Epoch  25
#             Loss   Accuracy
#  Train     57.4     75.19%
# Validate   54.07    76.61%
#
# Epoch  26
#             Loss   Accuracy
#  Train     56.53    75.28%
# Validate   54.94    76.40%
#
# Epoch  27
#             Loss   Accuracy
#  Train     56.38    74.55%
# Validate   52.93    77.86%
#
# Epoch  28
#             Loss   Accuracy
#  Train     55.47    75.03%
# Validate   57.91    75.17%
#
# Epoch  29
#             Loss   Accuracy
#  Train     55.07    76.19%
# Validate   53.36    76.86%
#
# Epoch  30
#             Loss   Accuracy
#  Train     54.88    75.08%
# Validate   53.56    77.05%
#
# Epoch  31
#             Loss   Accuracy
#  Train     54.57    76.13%
# Validate   52.78    77.30%
#
# Epoch  32
#             Loss   Accuracy
#  Train     53.74    75.97%
# Validate   53.03    76.77%
#
# Epoch  33
#             Loss   Accuracy
#  Train     53.72    76.47%
# Validate   52.62    77.02%
#
# Epoch  34
#             Loss   Accuracy
#  Train     53.04    76.43%
# Validate   51.53    77.69%
#
# Epoch  35
#             Loss   Accuracy
#  Train     52.85    76.07%
# Validate   49.53    78.99%
#
# Epoch  36
#             Loss   Accuracy
#  Train     52.61    77.19%
# Validate   52.38    77.22%
#
# Epoch  37
#             Loss   Accuracy
#  Train     52.78    77.03%
# Validate   53.06    76.90%
#
# Epoch  38
#             Loss   Accuracy
#  Train      51.8    77.34%
# Validate    50.9    77.92%
#
# Epoch  39
#             Loss   Accuracy
#  Train     51.64    77.22%
# Validate   49.51    78.85%
#
# Epoch  40
#             Loss   Accuracy
#  Train     51.52    76.61%
# Validate   50.77    78.16%
#
# Epoch  41
#             Loss   Accuracy
#  Train     51.22    77.63%
# Validate   51.8     77.58%
#
# Epoch  42
#             Loss   Accuracy
#  Train     50.44    77.92%
# Validate   49.56    78.78%
#
# Epoch  43
#             Loss   Accuracy
#  Train     50.08    77.41%
# Validate   51.8     77.29%
#
# Epoch  44
#             Loss   Accuracy
#  Train     49.98    77.09%
# Validate   50.79    78.37%
#
# Epoch  45
#             Loss   Accuracy
#  Train     50.21    78.10%
# Validate   49.07    79.15%
#
# Epoch  46
#             Loss   Accuracy
#  Train     49.86    78.45%
# Validate   51.02    77.89%
#
# Epoch  47
#             Loss   Accuracy
#  Train     49.74    77.85%
# Validate   49.06    78.78%
#
# Epoch  48
#             Loss   Accuracy
#  Train     49.65    77.28%
# Validate   55.02    76.31%
#
# Epoch  49
#             Loss   Accuracy
#  Train     49.49    78.40%
# Validate   50.85    77.93%
#
# Epoch  50
#             Loss   Accuracy
#  Train     48.53    77.48%
# Validate   52.51    77.18%

# %%
# PLOT3
plot_acc(dropout_train_accuracies, dropout_validate_accuracies, "train", "validate ")
